# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
data = requests.get(standings_url)

# %%
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202305311" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertB
# ...

# %%
from bs4 import BeautifulSoup

# %%
r = requests.get('https://fbref.com/en/comps/12/La-Liga-Stats')

# %%
soup = BeautifulSoup(r.content)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/206d90db/Barcelona-Stats',
#  '/en/squads/53a2f082/Real-Madrid-Stats',
#  '/en/squads/db3b9613/Atletico-Madrid-Stats',
#  '/en/squads/e31d1cd9/Real-Sociedad-Stats',
#  '/en/squads/2a8183b3/Villarreal-Stats',
#  '/en/squads/fc536746/Real-Betis-Stats',
#  '/en/squads/03c57e2b/Osasuna-Stats',
#  '/en/squads/2b390eca/Athletic-Club-Stats',
#  '/en/squads/9024a00a/Girona-Stats',
#  '/en/squads/98e8af82/Rayo-Vallecano-Stats',
#  '/en/squads/ad2be733/Sevilla-Stats',
#  '/en/squads/2aa12281/Mallorca-Stats',
#  '/en/squads/ee7c297c/Cadiz-Stats',
#  '/en/squads/7848bd64/Getafe-Stats',
#  '/en/squads/dcc91a7b/Valencia-Stats',
#  '/en/squads/78ecf4bb/Almeria-Stats',
#  '/en/squads/f25da7fb/Celta-Vigo-Stats',
#  '/en/squads/17859612/Valladolid-Stats',
#  '/en/squads/a8661628/Espanyol-Stats',
#  '/en/squads/6c8b07df/Elche-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/206d90db/Barcelona-Stats',
#  'https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/e31d1cd9/Real-Sociedad-Stats',
#  'https://fbref.com/en/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/en/squads/fc536746/Real-Betis-Stats',
#  'https://fbref.com/en/squads/03c57e2b/Osasuna-Stats',
#  'https://fbref.com/en/squads/2b390eca/Athletic-Club-Stats',
#  'https://fbref.com/en/squads/9024a00a/Girona-Stats',
#  'https://fbref.com/en/squads/98e8af82/Rayo-Vallecano-Stats',
#  'https://fbref.com/en/squads/ad2be733/Sevilla-Stats',
#  'https://fbref.com/en/squads/2aa12281/Mallorca-Stats',
#  'https://fbref.com/en/squads/ee7c297c/Cadiz-Stats',
#  'https://fbref.com/en/squads/7848bd64/Getafe-Stats',
#  'https://fbref.com/en/squads/dcc91a7b/Valencia-Stats',
#  'https://fbref.com/en/squads/78ecf4bb/Almeria-Stats',
# ...

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
matches.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result GF GA  \
# 0  2022-08-13  21:00       La Liga  Matchweek 1  Sat  Home      D  0  0
# 1  2022-08-21  22:00       La Liga  Matchweek 2  Sun  Away      W  4  1
# 2  2022-08-28  19:30       La Liga  Matchweek 3  Sun  Home      W  4  0
# 3  2022-09-03  21:00       La Liga  Matchweek 4  Sat  Away      W  3  0
# 4  2022-09-07  21:00  Champions Lg  Group stage  Wed  Home      W  5  1
#
#             Opponent   xG  xGA  Poss  Attendance                Captain  \
# 0     Rayo Vallecano  1.9  0.5  67.0     81104.0        Sergio Busquets
# 1      Real Sociedad  2.1  0.8  58.0     36201.0  Marc-André ter Stegen
# 2         Valladolid  2.6  0.8  67.0     83972.0        Sergio Busquets
# 3            Sevilla  4.0  1.0  54.0     40233.0        Sergio Busquets
# 4  cz Viktoria Plzeň  2.3  0.8  76.0     77411.0          Sergi Roberto
#
#   Formation              Referee  Match Report Notes
# ...

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
#links = [l for l in links if l and 'all_comps/passing/' in l]

# %%
soup = BeautifulSoup(data.text)
links2 = soup.find_all('a')
links2 = [l.get("href") for l in links2]
links2 = [l for l in links2 if l and 'all_comps/passing/' in l]

# %%
links3 = soup.find_all('a')
links3 = [l.get("href") for l in links3]
links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]

# %%
links4 = soup.find_all('a')
links4 = [l.get("href") for l in links4]
links4 = [l for l in links4 if l and 'all_comps/gca/' in l]

# %%
links5 = soup.find_all('a')
links5 = [l.get("href") for l in links5]
links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]

# %%
links6 = soup.find_all('a')
links6 = [l.get("href") for l in links6]
links6 = [l for l in links6 if l and 'all_comps/possession/' in l]

# %%
links7 = soup.find_all('a')
links7 = [l.get("href") for l in links7]
links7 = [l for l in links7 if l and 'all_comps/defense/' in l]

# %%
links
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions']

# %%
links2
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing/Barcelona-Match-Logs-All-Competitions']

# %%
links3
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing_types/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing_types/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing_types/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/passing_types/Barcelona-Match-Logs-All-Competitions']

# %%
links4
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/gca/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/gca/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/gca/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/gca/Barcelona-Match-Logs-All-Competitions']

# %%
links5
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/keeper/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/keeper/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/keeper/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/keeper/Barcelona-Match-Logs-All-Competitions']

# %%
links6
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/possession/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/possession/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/possession/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/possession/Barcelona-Match-Logs-All-Competitions']

# %%
links7
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/defense/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/defense/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/defense/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/defense/Barcelona-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")#shooting
data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
passing = pd.read_html(data2.text, match="Passing")[0]
passing_types = pd.read_html(data3.text, match="Pass Types")[0]
gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
possession = pd.read_html(data6.text, match="Possession")[0]
defense = pd.read_html(data7.text, match="Defensive Actions")[0]

# %%
gca.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 gca.head()
#
# NameError: name 'gca' is not defined

# %%
shooting.columns = shooting.columns.droplevel()
passing.columns = passing.columns.droplevel()
passing_types.columns = passing_types.columns.droplevel()
gca.columns = gca.columns.droplevel()
keeper.columns = keeper.columns.droplevel()
possession.columns = possession.columns.droplevel()
defense.columns = defense.columns.droplevel()

# %%
passing.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'Cmp', 'Att',
#        'Cmp%', 'Cmp', 'Att', 'Cmp%', 'Cmp', 'Att', 'Cmp%', 'Ast', 'xAG', 'xA',
#        'KP', '1/3', 'PPA', 'CrsPA', 'PrgP', 'Match Report'],
#       dtype='object')

# %%
passing_types.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK',
#        'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks', 'Match Report'],
#       dtype='object')

# %%
gca.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def',
#        'GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def',
#        'Match Report'],
#       dtype='object')

# %%
keeper.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-',
#        'PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%', 'Att', 'Thr',
#        'Launch%', 'AvgLen', 'Att', 'Launch%', 'AvgLen', 'Opp', 'Stp', 'Stp%',
#        '#OPA', 'AvgDist', 'Match Report'],
#       dtype='object')

# %%
possession.rename(columns={'Att 3rd': 'Att_3rd'}, inplace=True)
possession.rename(columns={'Att Pen': 'Att_Pen'}, inplace=True)
possession.rename(columns={'Att': 'Atta'}, inplace=True)

# %%
possession.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd',
#        'Att_3rd', 'Att_Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%',
#        'Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis',
#        'Rec', 'PrgR', 'Match Report'],
#       dtype='object')

# %%
defense.rename(columns={'Att': 'Atta'}, inplace=True)

# %%
defense.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl',
#        'Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr',
#        'Err', 'Match Report'],
#       dtype='object')

# %%
gca
# Out:
#           Date   Time                 Comp                     Round  Day  \
# 0   2022-08-13  21:00              La Liga               Matchweek 1  Sat
# 1   2022-08-21  22:00              La Liga               Matchweek 2  Sun
# 2   2022-08-28  19:30              La Liga               Matchweek 3  Sun
# 3   2022-09-03  21:00              La Liga               Matchweek 4  Sat
# 4   2022-09-07  21:00         Champions Lg               Group stage  Wed
# 5   2022-09-10  18:30              La Liga               Matchweek 5  Sat
# 6   2022-09-13  21:00         Champions Lg               Group stage  Tue
# 7   2022-09-17  16:15              La Liga               Matchweek 6  Sat
# 8   2022-10-01  21:00              La Liga               Matchweek 7  Sat
# 9   2022-10-04  21:00         Champions Lg               Group stage  Tue
# 10  2022-10-09  21:00              La Liga               Matchweek 8  Sun
# 11  2022-10-12  21:00         Champions Lg               Group stage  Wed
# ...

# %%
team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att_3rd','Att_Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

# %%
team_data.shape
# Out:
# (52, 155)

# %%
team_data
# Out:
#           Date   Time                 Comp                     Round  Day  \
# 0   2022-08-13  21:00              La Liga               Matchweek 1  Sat
# 1   2022-08-21  22:00              La Liga               Matchweek 2  Sun
# 2   2022-08-28  19:30              La Liga               Matchweek 3  Sun
# 3   2022-09-03  21:00              La Liga               Matchweek 4  Sat
# 4   2022-09-07  21:00         Champions Lg               Group stage  Wed
# 5   2022-09-10  18:30              La Liga               Matchweek 5  Sat
# 6   2022-09-13  21:00         Champions Lg               Group stage  Tue
# 7   2022-09-17  16:15              La Liga               Matchweek 6  Sat
# 8   2022-10-01  21:00              La Liga               Matchweek 7  Sat
# 9   2022-10-04  21:00         Champions Lg               Group stage  Tue
# 10  2022-10-09  21:00              La Liga               Matchweek 8  Sun
# 11  2022-10-12  21:00         Champions Lg               Group stage  Wed
# ...

# %%
team_data.shape
# Out:
# (52, 155)

# %%
years = list(range(2019, 2017, -1))

# %%
years
# Out:
# [2019, 2018]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]
    time.sleep(3)
    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    time.sleep(3)
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    time.sleep(3)
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        time.sleep(3)
        links = [l.get("href") for l in soup.find_all('a')]
        links2 = [l.get("href") for l in soup.find_all('a')]
        links3 = [l.get("href") for l in soup.find_all('a')]
        links4 = [l.get("href") for l in soup.find_all('a')]
        links5 = [l.get("href") for l in soup.find_all('a')]
        links6 = [l.get("href") for l in soup.find_all('a')]
        links7 = [l.get("href") for l in soup.find_all('a')]
        time.sleep(3)
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
        links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
        links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
        links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
        links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
        links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
        time.sleep(3)
        data = requests.get(f"https://fbref.com{links[0]}")
        time.sleep(1)
        data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
        time.sleep(1)
        data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
        time.sleep(1)
        data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
        time.sleep(1)
        data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
        time.sleep(1)
        data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
        time.sleep(1)
        data7 = requests.get(f"https://fbref.com{links7[0]}")#defense
    
        shooting = pd.read_html(data.text, match="Shooting")[0]
        passing = pd.read_html(data2.text, match="Passing")[0]
        passing_types = pd.read_html(data3.text, match="Pass Types")[0]
        gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
        keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
        possession = pd.read_html(data6.text, match="Possession")[0]
        defense = pd.read_html(data7.text, match="Defensive Actions")[0]
        
        shooting.columns = shooting.columns.droplevel()
        passing.columns = passing.columns.droplevel()
        passing_types.columns = passing_types.columns.droplevel()
        gca.columns = gca.columns.droplevel()
        keeper.columns = keeper.columns.droplevel()
        possession.columns = possession.columns.droplevel()
        defense.columns = defense.columns.droplevel()
        
        possession.rename(columns={'Att': 'Atta'}, inplace=True)
        defense.rename(columns={'Att': 'Atta'}, inplace=True)
        try:
            team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
            team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
            team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
            team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
            team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
            team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
            team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "La Liga"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)
        
    print(f"{year} done")
# Out:
# 2019 done
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\users\kavin\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
# ...

# %%
len(all_matches)
# Out:
# 110

# %%
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup

# %%
year = 2023
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 50
#      48 gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
#      49 keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
# ---> 50 possession = pd.read_html(data6.text, match="Possession")[0]
#      51 defense = pd.read_html(data7.text, match="Defensive Actions")[0]
#      53 shooting.columns = shooting.columns.droplevel()
#
# File c:\users\kavin\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
# ...

# %%
year = 2022
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# 2022 done

# %%
all_matches = []
year = 2021
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# 2021 done

# %%
year = 2020
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# 2020 done

# %%
year = 2019
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# 2019 done

# %%
year = 2018
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# 2018 done

# %%
year = 2017
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
time.sleep(2)
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = [l.get("href") for l in standings_table.find_all('a')]
links = [l for l in links if '/squads/' in l]
team_urls = [f"https://fbref.com{l}" for l in links]

previous_season = soup.select("a.prev")[0].get("href")
standings_url = f"https://fbref.com{previous_season}"

for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    time.sleep(2)
    links = [l.get("href") for l in soup.find_all('a')]
    links2 = [l.get("href") for l in soup.find_all('a')]
    links3 = [l.get("href") for l in soup.find_all('a')]
    links4 = [l.get("href") for l in soup.find_all('a')]
    links5 = [l.get("href") for l in soup.find_all('a')]
    links6 = [l.get("href") for l in soup.find_all('a')]
    links7 = [l.get("href") for l in soup.find_all('a')]
    time.sleep(1)
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    links2 = [l for l in links2 if l and 'all_comps/passing/' in l]
    links3 = [l for l in links3 if l and 'all_comps/passing_types/' in l]
    links4 = [l for l in links4 if l and 'all_comps/gca/' in l]
    links5 = [l for l in links5 if l and 'all_comps/keeper/' in l]
    links6 = [l for l in links6 if l and 'all_comps/possession/' in l]
    links7 = [l for l in links7 if l and 'all_comps/defense/' in l]
    time.sleep(1)
    data = requests.get(f"https://fbref.com{links[0]}")
    data2 = requests.get(f"https://fbref.com{links2[0]}")#passing
    data3 = requests.get(f"https://fbref.com{links3[0]}")#passing_types
    data4 = requests.get(f"https://fbref.com{links4[0]}")#gca
    data5 = requests.get(f"https://fbref.com{links5[0]}")#keeper
    data6 = requests.get(f"https://fbref.com{links6[0]}")#possession
    data7 = requests.get(f"https://fbref.com{links7[0]}")#defense

    shooting = pd.read_html(data.text, match="Shooting")[0]
    passing = pd.read_html(data2.text, match="Passing")[0]
    passing_types = pd.read_html(data3.text, match="Pass Types")[0]
    gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
    keeper = pd.read_html(data5.text, match="Goalkeeping")[0]
    possession = pd.read_html(data6.text, match="Possession")[0]
    defense = pd.read_html(data7.text, match="Defensive Actions")[0]

    shooting.columns = shooting.columns.droplevel()
    passing.columns = passing.columns.droplevel()
    passing_types.columns = passing_types.columns.droplevel()
    gca.columns = gca.columns.droplevel()
    keeper.columns = keeper.columns.droplevel()
    possession.columns = possession.columns.droplevel()
    defense.columns = defense.columns.droplevel()

    possession.rename(columns={'Att': 'Atta'}, inplace=True)
    defense.rename(columns={'Att': 'Atta'}, inplace=True)
    try:
        team_data = matches.merge(shooting[["Date","Gls","Sh","SoT","SoT%","G/Sh","G/SoT","Dist","FK","PK","PKatt","xG","npxG","npxG/Sh","G-xG","np:G-xG"]], on="Date")
        team_data = team_data.merge(passing[['Date','Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist','Ast', 'xAG', 'xA','KP', '1/3', 'PPA', 'CrsPA', 'PrgP']], on="Date")
        team_data = team_data.merge(passing_types[['Date','Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks']], on="Date")
        team_data = team_data.merge(gca[['Date','SCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def','GCA', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def']], on="Date")
        team_data = team_data.merge(keeper[["Date", 'SoTA', 'GA', 'Saves', 'Save%', 'CS', 'PSxG', 'PSxG+/-','PKatt', 'PKA', 'PKsv', 'PKm', 'Cmp', 'Att', 'Cmp%']], on="Date")
        team_data = team_data.merge(possession[["Date",'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd','Att Pen', 'Live', 'Atta', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']], on="Date")
        team_data = team_data.merge(defense[["Date",'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl','Atta', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr','Err']], on="Date")

    except ValueError:
        continue
    team_data = team_data[team_data["Comp"] == "La Liga"]

    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)

print(f"{year} done")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 46
#      43 data7 = requests.get(f"https://fbref.com{links7[0]}")#defense
#      45 shooting = pd.read_html(data.text, match="Shooting")[0]
# ---> 46 passing = pd.read_html(data2.text, match="Passing")[0]
#      47 passing_types = pd.read_html(data3.text, match="Pass Types")[0]
#      48 gca = pd.read_html(data4.text, match="Goal and Shot Creation")[0]
#
# File c:\users\kavin\appdata\local\programs\python\python39\lib\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
# ...

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time     comp         round  day venue result gf ga_x  \
# 0   2021-08-14  22:00  La Liga   Matchweek 1  Sat  Away      W  4    1
# 1   2021-08-22  22:00  La Liga   Matchweek 2  Sun  Away      D  3    3
# 2   2021-08-28  22:00  La Liga   Matchweek 3  Sat  Away      W  1    0
# 3   2021-09-12  21:00  La Liga   Matchweek 4  Sun  Home      W  5    2
# 5   2021-09-19  21:00  La Liga   Matchweek 5  Sun  Away      W  2    1
# ..         ...    ...      ...           ...  ...   ...    ... ..  ...
# 36  2022-05-01  14:00  La Liga  Matchweek 34  Sun  Away      D  1    1
# 37  2022-05-08  18:30  La Liga  Matchweek 35  Sun  Away      D  1    1
# 38  2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      D  1    1
# 39  2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  0    2
# 40  2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0    2
#
#          opponent  ...  lost  blocks_y   sh  pass   int tkl+int   clr  err  \
# ...

# %%
match_df.shape
# Out:
# (4160, 157)

# %%
match_df.to_csv("matches_laliga.csv")
